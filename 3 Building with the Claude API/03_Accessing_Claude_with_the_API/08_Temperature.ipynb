# %%
# Load env variables and create client
import os
import debugpy
import json
from dotenv import load_dotenv
from anthropic import Anthropic
from IPython.display import display
import pprint, shutil
import textwrap

load_dotenv()
if not os.getenv("ANTHROPIC_API_KEY"):
    exit("No API key found in environment variables")

client = Anthropic()
model = "claude-haiku-4-5"

def myprint(messages):
    width = shutil.get_terminal_size().columns
    for line in json.dumps(messages, indent=2, ensure_ascii=False).splitlines():
        indent = len(line) - len(line.lstrip())
        print(textwrap.fill(line, width=width, subsequent_indent=' ' * (indent + 2)))

def myprint2(answer):
    width = shutil.get_terminal_size().columns
    for line in answer.splitlines():
        indent = len(line) - len(line.lstrip())
        print(textwrap.fill(line, width=width, subsequent_indent=' ' * (indent + 2)))

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system

    print("temperature",temperature)
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(
    messages,
    "Generate Movie Ideas",
)

# %%
# Low temperature - more predictable
print(chat(messages, temperature=0.0))
# Out:
# temperature 0.0
# # 10 Movie Ideas
#
# ## 1. **The Last Librarian**
# A librarian discovers that books are literally disappearing from reality. She must protect the last library on Earth while uncovering who's erasing human knowledge—and why.
#
# ## 2. **Neon Requiem**
# A washed-up jazz musician in a cyberpunk city gets one final gig that could either save her life or end it. Features stunning visuals and an original soundtrack.
#
# ## 3. **The Inheritance**
# A woman inherits her estranged father's mansion, only to find it's a sentient entity that's been waiting for her. It has its own agenda.
#
# ## 4. **Frequency**
# A deaf sound engineer can "see" sound waves as colors. When she witnesses a crime through her unique perception, no one believes her—until she must prove it.
#
# ## 5. **The Gardeners**
# In a post-apocalyptic world, a community of urban farmers discovers their crops are evolving with consciousness. They must decide whether to destroy or communicate with them.
#
# ## 6. **Borrowed Time**
# People can literally trade years of their lives as currency. A black market dealer gets caught between a crime boss and a mysterious buyer who wants to live forever.
#
# ## 7. **The Passenger**
# A rideshare driver picks up the same mysterious passenger every night. Each ride reveals a different timeline where their lives took different paths.
#
# ## 8. **Rust & Roses**
# An old factory worker and a young environmental activist must work together to save a dying industrial town—and discover unexpected love in the process.
#
# ## 9. **The Forgetting**
# A memory thief steals people's happiest moments to sell on the black market. When she steals the wrong memory, she uncovers a conspiracy.
#
# ## 10. **Echoes**
# A grief counselor realizes her clients aren't just mourning—they're being haunted. She must uncover what's keeping the dead from moving on.
#
# ---
#
# Which genre or theme interests you most? I can expand on any of these!

# %%
# High temperature - more creative
print(chat(messages, temperature=1.0))
# Out:
# temperature 1.0
# # 10 Movie Ideas
#
# ## 1. **The Last Librarian**
# A librarian discovers that books are literally disappearing from reality as people stop reading them. She must find a way to preserve human knowledge before entire histories vanish from existence.
#
# ## 2. **Frequency**
# A sound engineer realizes she can hear conversations from parallel universes through her equipment. She makes contact with an alternate version of herself living a completely different life.
#
# ## 3. **The Apology**
# A woman receives a mysterious letter apologizing for something she doesn't remember. As she investigates, she uncovers a forgotten tragedy that rewrites everything she knows about her family.
#
# ## 4. **Neon Roots**
# A street artist's murals come to life at midnight, showing visions of the neighborhood's past. She uses them to solve a decades-old cold case.
#
# ## 5. **The Inheritance of Dust**
# An estranged son returns to his father's desert ranch to claim his inheritance, only to discover his father left him a series of mysterious coordinates leading to buried secrets.
#
# ## 6. **Mirror Lake**
# A photographer discovers her reflections in an isolated lake's water are acting independently, living a life she abandoned years ago.
#
# ## 7. **The Last Commute**
# On the final day before autonomous vehicles replace all human drivers, a taxi driver picks up four passengers, each harboring a life-changing secret.
#
# ## 8. **Borrowed Time**
# A woman finds she can trade days of her life with strangers to experience their lives. She becomes addicted until she realizes the dangerous cost.
#
# ## 9. **The Forgotten Garden**
# An elderly woman's garden grows impossible plants that grant temporary abilities. Neighbors and strangers begin appearing, desperate for their magic.
#
# ## 10. **Static**
# A recluse discovers that white noise on old TV channels contains hidden messages from someone—or something—trying to communicate from inside the broadcast signal.
#
# ---
#
# Which genre or theme interests you most?
