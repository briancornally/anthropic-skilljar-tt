# %%
# Load env variables and create client
import os
import debugpy
import json
from dotenv import load_dotenv
from anthropic import Anthropic
from IPython.display import display
import pprint, shutil
import textwrap

load_dotenv()
if not os.getenv("ANTHROPIC_API_KEY"):
    exit("No API key found in environment variables")

client = Anthropic()
model = "claude-haiku-4-5"

def myprint(messages):
    width = shutil.get_terminal_size().columns
    for line in json.dumps(messages, indent=2, ensure_ascii=False).splitlines():
        indent = len(line) - len(line.lstrip())
        print(textwrap.fill(line, width=width, subsequent_indent=' ' * (indent + 2)))

def myprint2(answer):
    width = shutil.get_terminal_size().columns
    for line in answer.splitlines():
        indent = len(line) - len(line.lstrip())
        print(textwrap.fill(line, width=width, subsequent_indent=' ' * (indent + 2)))

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(
    messages,
    "Write a Python function that checks a string for duplicate characters.",
)

answer = chat(messages)
print(answer)
# Out:
# # Python Function to Check for Duplicate Characters
#
# Here are several approaches, from simple to advanced:
#
# ## 1. **Simple Approach Using Set**
# ```python
# def has_duplicates(string):
#     """
#     Check if string has duplicate characters.
#     Returns True if duplicates exist, False otherwise.
#     """
#     return len(string) != len(set(string))
#
# # Usage
# print(has_duplicates("hello"))      # True (l appears twice)
# print(has_duplicates("world"))      # False
# print(has_duplicates("aabbcc"))     # True
# ```
#
# ## 2. **Return Duplicate Characters**
# ```python
# def find_duplicates(string):
#     """
#     Return a set of duplicate characters found in the string.
#     """
#     seen = set()
#     duplicates = set()
#
#     for char in string:
#         if char in seen:
#             duplicates.add(char)
#         seen.add(char)
#
#     return duplicates
#
# # Usage
# print(find_duplicates("hello"))      # {'l'}
# print(find_duplicates("aabbcc"))     # {'a', 'b', 'c'}
# print(find_duplicates("world"))      # set()
# ```
#
# ## 3. **Count Occurrences (Most Detailed)**
# ```python
# from collections import Counter
#
# def count_duplicates(string):
#     """
#     Return a dictionary with character counts for duplicated characters.
#     """
#     char_count = Counter(string)
#     return {char: count for char, count in char_count.items() if count > 1}
#
# # Usage
# print(count_duplicates("hello"))     # {'l': 2}
# print(count_duplicates("aabbcc"))    # {'a': 2, 'b': 2, 'c': 2}
# print(count_duplicates("world"))     # {}
# ```
#
# ## 4. **Case-Insensitive Version**
# ```python
# def has_duplicates_case_insensitive(string):
#     """
#     Check for duplicates ignoring case.
#     """
#     lowercase = string.lower()
#     return len(lowercase) != len(set(lowercase))
#
# # Usage
# print(has_duplicates_case_insensitive("Hello"))     # True (l appears twice)
# print(has_duplicates_case_insensitive("HeLLo"))     # True
# ```
#
# ## 5. **Ignore Spaces and Special Characters**
# ```python
# def has_duplicates_alphanumeric(string):
#     """
#     Check for duplicates considering only alphanumeric characters.
#     """
#     alphanumeric = ''.join(char.lower() for char in string if char.isalnum())
#     return len(alphanumeric) != len(set(alphanumeric))
#
# # Usage
# print(has_duplicates_alphanumeric("Hello World"))   # True
# print(has_duplicates_alphanumeric("a-b-c"))        # False
# ```
#
# ## 6. **Comprehensive Function with Options**
# ```python
# def check_duplicates(string, ignore_case=True, ignore_spaces=True):
#     """
#     Comprehensive duplicate checker with options.
#
#     Args:
#         string: Input string to check
#         ignore_case: If True, treats 'A' and 'a' as duplicates
#         ignore_spaces: If True, ignores spaces
#
#     Returns:
#         Dictionary with 'has_duplicates' and 'duplicate_chars'
#     """
#     # Process string
#     processed = string
#     if ignore_case:
#         processed = processed.lower()
#     if ignore_spaces:
#         processed = processed.replace(' ', '')
#
#     # Find duplicates
#     seen = set()
#     duplicates = set()
#
#     for char in processed:
#         if char in seen:
#             duplicates.add(char)
#         seen.add(char)
#
#     return {
#         'has_duplicates': len(duplicates) > 0,
#         'duplicate_chars': duplicates
#     }
#
# # Usage
# result = check_duplicates("Hello World")
# print(result)  # {'has_duplicates': True, 'duplicate_chars': {'

# %%
messages = []

add_user_message(
    messages,
    "Write a Python function that checks a string for duplicate characters.",
)
answer = chat(messages, system="You are a Python engineer who writes very concise code.")

print(answer)
# Out:
# # Simple and concise solutions:
#
# ```python
# # Using set comparison
# def has_duplicates(s: str) -> bool:
#     return len(s) != len(set(s))
#
# # Using Counter
# from collections import Counter
# def has_duplicates(s: str) -> bool:
#     return any(count > 1 for count in Counter(s).values())
#
# # Finding which characters are duplicated
# def find_duplicates(s: str) -> set:
#     return {c for c in s if s.count(c) > 1}
# ```
#
# **Examples:**
# ```python
# has_duplicates("hello")      # True (l appears twice)
# has_duplicates("world")      # False
# has_duplicates("aabbcc")     # True
#
# find_duplicates("hello")     # {'l'}
# find_duplicates("mississippi") # {'s', 'i'}
# ```
#
# **Explanation:**
# - **First version**: Most efficient - compares string length to unique characters
# - **Second version**: Using Counter for readability
# - **Third version**: Returns the actual duplicate characters as a set
#
# Choose the first for best performance (O(n) time, O(n) space).
