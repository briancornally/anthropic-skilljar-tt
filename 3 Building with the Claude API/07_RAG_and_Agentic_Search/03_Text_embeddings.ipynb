# %%
# Install VoyageAI lib
# %pip install voyageai
# Out:
# Collecting voyageai
#   Downloading voyageai-0.2.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting aiohttp<4.0,>=3.5 (from voyageai)
#   Downloading aiohttp-3.13.5-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting aiolimiter<2.0.0,>=1.1.0 (from voyageai)
#   Downloading aiolimiter-1.2.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting numpy>=1.11 (from voyageai)
#   Using cached numpy-2.4.4-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting requests<3.0,>=2.20 (from voyageai)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting tenacity>=8.0.1 (from voyageai)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0,>=3.5->voyageai)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading frozenlist-1.8.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading multidict-6.7.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading propcache-0.5.2-cp314-cp314-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading yarl-1.23.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0,>=2.20->voyageai)
#   Using cached charset_normalizer-3.4.7-cp314-cp314-macosx_10_15_universal2.whl.metadata (40 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/brian/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages (from requests<3.0,>=2.20->voyageai) (3.13)
# Collecting urllib3<3,>=1.26 (from requests<3.0,>=2.20->voyageai)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/brian/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages (from requests<3.0,>=2.20->voyageai) (2026.4.22)
# Downloading voyageai-0.2.4-py3-none-any.whl (20 kB)
# Downloading aiohttp-3.13.5-cp314-cp314-macosx_11_0_arm64.whl (499 kB)
# Downloading aiolimiter-1.2.1-py3-none-any.whl (6.7 kB)
# Downloading multidict-6.7.1-cp314-cp314-macosx_11_0_arm64.whl (43 kB)
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached charset_normalizer-3.4.7-cp314-cp314-macosx_10_15_universal2.whl (309 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading yarl-1.23.0-cp314-cp314-macosx_11_0_arm64.whl (86 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp314-cp314-macosx_11_0_arm64.whl (49 kB)
# Using cached numpy-2.4.4-cp314-cp314-macosx_14_0_arm64.whl (5.2 MB)
# Downloading propcache-0.5.2-cp314-cp314-macosx_11_0_arm64.whl (54 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Installing collected packages: urllib3, tenacity, propcache, numpy, multidict, frozenlist, charset_normalizer, attrs, aiolimiter, aiohappyeyeballs, yarl, requests, aiosignal, aiohttp, voyageai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [voyageai]/15 [aiohttp]st]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiolimiter-1.2.1 aiosignal-1.4.0 attrs-26.1.0 charset_normalizer-3.4.7 frozenlist-1.8.0 multidict-6.7.1 numpy-2.4.4 propcache-0.5.2 requests-2.34.2 tenacity-9.1.4 urllib3-2.7.0 voyageai-0.2.4 yarl-1.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Client Setup
from dotenv import load_dotenv
import voyageai

load_dotenv()

client = voyageai.Client()

# %%
# Chunk by section
import re


def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
# Embedding Generation
def generate_embedding(text, model="voyage-3-large", input_type="query"):
    result = client.embed([text], model=model, input_type=input_type)

    return result.embeddings[0]

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_section(text)

generate_embedding(chunks[0])
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:1450, in HTTPConnection.getresponse(self)
#    1449 try:
# -> 1450     response.begin()
#    1451 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:336, in HTTPResponse.begin(self)
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socket.py:725, in SocketIO.readinto(self, b)
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/requests/adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:842, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840     new_e = ProtocolError("Connection aborted.", new_e)
# --> 842 retries = retries.increment(
#     843     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     844 )
#     845 retries.sleep()
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/urllib3/util/retry.py:498, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     497 if read is False or method is None or not self._is_method_retryable(method):
# --> 498     raise reraise(type(error), error, _stacktrace)
#     499 elif read is not None:
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:1450, in HTTPConnection.getresponse(self)
#    1449 try:
# -> 1450     response.begin()
#    1451 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:336, in HTTPResponse.begin(self)
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socket.py:725, in SocketIO.readinto(self, b)
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/voyageai/api_resources/api_requestor.py:314, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     313 try:
# --> 314     result = _thread_context.session.request(
#     315         method,
#     316         abs_url,
#     317         headers=headers,
#     318         data=data,
#     319         files=files,
#     320         stream=stream,
#     321         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     322         proxies=_thread_context.session.proxies,
#     323     )
#     324 except requests.exceptions.Timeout as e:
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/requests/sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/requests/sessions.py:784, in Session.send(self, request, **kwargs)
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/requests/adapters.py:711, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     710 except (ProtocolError, OSError) as err:
# --> 711     raise ConnectionError(err, request=request)
#     713 except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[5], line 6
#       2     text = f.read()
#       3
#       4 chunks = chunk_by_section(text)
#       5
# ----> 6 generate_embedding(chunks[0])
#
# Cell In[4], line 3, in generate_embedding(text, model, input_type)
#       2 def generate_embedding(text, model="voyage-3-large", input_type="query"):
# ----> 3     result = client.embed([text], model=model, input_type=input_type)
#       4
#       5     return result.embeddings[0]
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/voyageai/client.py:63, in Client.embed(self, texts, model, input_type, truncation)
#      55     model = voyageai.VOYAGE_EMBED_DEFAULT_MODEL
#      56     warnings.warn(
#      57         f"The `model` argument is not specified and defaults to {voyageai.VOYAGE_EMBED_DEFAULT_MODEL}. "
#      58         "It will be a required argument in the future. We recommend to specify the model when using this "
#      59         "function. Please see https://docs.voyageai.com/docs/embeddings for the list of latest models "
#      60         "provided by Voyage AI."
#      61     )
# ---> 63 for attempt in self.retry_controller:
#      64     with attempt:
#      65         response = voyageai.Embedding.create(
#      66             input=texts,
#      67             model=model,
#    (...)     70             **self._params,
#      71         )
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/tenacity/__init__.py:438, in BaseRetrying.__iter__(self)
#     436 retry_state = RetryCallState(self, fn=None, args=(), kwargs={})
#     437 while True:
# --> 438     do = self.iter(retry_state=retry_state)
#     439     if isinstance(do, DoAttempt):
#     440         yield AttemptManager(retry_state=retry_state)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/voyageai/client.py:65, in Client.embed(self, texts, model, input_type, truncation)
#      63 for attempt in self.retry_controller:
#      64     with attempt:
# ---> 65         response = voyageai.Embedding.create(
#      66             input=texts,
#      67             model=model,
#      68             input_type=input_type,
#      69             truncation=truncation,
#      70             **self._params,
#      71         )
#      73 result = EmbeddingsObject(response)
#      74 return result
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/voyageai/api_resources/embedding.py:22, in Embedding.create(cls, *args, **kwargs)
#      19 if not user_provided_encoding_format:
#      20     kwargs["encoding_format"] = "base64"
# ---> 22 response = super().create(*args, **kwargs)
#      24 # If a user specifies base64, we'll just return the encoded string.
#      25 # This is only for the default case.
#      26 if not user_provided_encoding_format:
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/voyageai/api_resources/api_resource.py:47, in APIResource.create(cls, api_key, api_base, request_id, request_timeout, **params)
#      34 @classmethod
#      35 def create(
#      36     cls,
#    (...)     41     **params,
#      42 ):
#      43     requestor, url, params, headers = cls.__prepare_create_request(
#      44         api_key, api_base, **params
#      45     )
# ---> 47     response = requestor.request(
#      48         "post",
#      49         url,
#      50         params=params,
#      51         headers=headers,
#      52         request_id=request_id,
#      53         request_timeout=request_timeout,
#      54     )
#      56     obj = convert_to_voyage_response(response)
#      57     return obj
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/voyageai/api_resources/api_requestor.py:137, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     126 def request(
#     127     self,
#     128     method,
#    (...)    135     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     136 ) -> VoyageHttpResponse:
# --> 137     result = self.request_raw(
#     138         method.lower(),
#     139         url,
#     140         params=params,
#     141         supplied_headers=headers,
#     142         files=files,
#     143         stream=stream,
#     144         request_id=request_id,
#     145         request_timeout=request_timeout,
#     146     )
#     147     resp = self._interpret_response(result)
#     148     return resp
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/_/tt/ai-claude-tt/3 Building with the Claude API/.venv/lib/python3.14/site-packages/voyageai/api_resources/api_requestor.py:327, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     325     raise error.Timeout("Request timed out: {}".format(e)) from e
#     326 except requests.exceptions.RequestException as e:
# --> 327     raise error.APIConnectionError(
#     328         "Error communicating with VoyageAI: {}".format(e)
#     329     ) from e
#     330 util.log_debug(
#     331     "Voyage API response",
#     332     path=abs_url,
#    (...)    335     request_id=result.headers.get("X-Request-Id"),
#     336 )
#     337 # Don't read the whole stream for debug logging unless necessary.
#
# APIConnectionError: Error communicating with VoyageAI: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
