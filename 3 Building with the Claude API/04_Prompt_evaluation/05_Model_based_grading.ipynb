# %%
# Load env variables and create client
from anthropic import Anthropic
from dotenv import load_dotenv
from IPython.display import display
from IPython.display import Markdown
import debugpy
import json
import os
import pprint, shutil
import textwrap
load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Parse AWS S3 Bucket Name from URI\n\nHere are several solutions depending on your needs:\n\n## 1. **Simple String Parsing (Python)**\n```python\ndef parse_s3_bucket(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    # Remove s3:// prefix and get the first part\n    return s3_uri.replace(\"s3://\", \"\").split(\"/\")[0]\n\n# Test\nprint(parse_s3_bucket(\"s3://my-bucket/key/path\"))  # Output: my-bucket\n```\n\n## 2. **Using Regular Expressions (Python)**\n```python\nimport re\n\ndef parse_s3_bucket(s3_uri):\n    \"\"\"Extract bucket name using regex\"\"\"\n    match = re.match(r\"s3://([^/]+)\", s3_uri)\n    return match.group(1) if match else None\n\n# Test\nprint(parse_s3_bucket(\"s3://my-bucket/key/path\"))  # Output: my-bucket\n```\n\n## 3. **Using urllib (Python)**\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket(s3_uri):\n    \"\"\"Extract bucket name using urllib\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Test\nprint(parse_s3_bucket(\"s3://my-bucket/key/path\"))  # Output: my-bucket\n```\n\n## 4. **Using boto3 (AWS SDK)**\n```python\nfrom botocore.compat import urlparse\n\ndef parse_s3_bucket(s3_uri):\n    \"\"\"Extract bucket and key using boto3\"\"\"\n    parsed = urlparse(s3_uri)\n    bucket = parsed.netloc\n    key = parsed.path.lstrip('/')\n    return bucket, key\n\n# Test\nbucket, key = parse_s3_bucket(\"s3://my-bucket/key/path\")\nprint(f\"Bucket: {bucket}, Key: {key}\")\n# Output: Bucket: my-bucket, Key: key/path\n```\n\n## 5. **JavaScript/Node.js**\n```javascript\nfunction parseS3Bucket(s3Uri) {\n    return s3Uri.replace(\"s3://\", \"\").split(\"/\")[0];\n}\n\n// Test\nconsole.log(parseS3Bucket(\"s3://my-bucket/key/path\"));  // Output: my-bucket\n```\n\n## 6. **Bash/Shell Script**\n```bash\n#!/bin/bash\n\nparse_s3_bucket() {\n    echo \"$1\" | sed 's|s3://||' | cut -d'/' -f1\n}\n\nparse_s3_bucket \"s3://my-bucket/key/path\"  # Output: my-bucket\n```\n\n---\n\n## **Recommendation**\n\n- **Simple cases**: Use option #1 (string parsing)\n- **Production code with boto3**: Use option #4 (handles edge cases better)\n- **Validation needed**: Use option #2 (regex ensures S3 URI format)\n\nAll solutions handle the standard S3 URI format: `s3://bucket-name/key/path`",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (s3://bucket-name/key/path)",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution is well-structured and provides breadth across multiple languages and approaches, which is valuable for AWS developers. However, it prioritizes simplicity and ease of understanding over robustness. For AWS use cases, production code typically requires validation and error handling. The regex approach (Option #2) should have been recommended more strongly for production use. Additionally, missing discussion of common edge cases and AWS-specific scenarios (like Spark S3A URIs or bucket names with dots) limits practical applicability."
#   },
#   {
#     "output": "# AWS Lambda Function JSON Configuration\n\n```json\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::123456789012:role/lambda-execution-role\",\n  \"Handler\": \"index.handler\",\n  \"Timeout\": 30,\n  \"MemorySize\": 256,\n  \"Description\": \"Basic Lambda function configuration\",\n  \"EphemeralStorage\": {\n    \"Size\": 512\n  },\n  \"Environment\": {\n    \"Variables\": {\n      \"ENV\": \"development\",\n      \"LOG_LEVEL\": \"INFO\"\n    }\n  },\n  \"Tags\": {\n    \"Environment\": \"dev\",\n    \"Project\": \"my-project\",\n    \"Owner\": \"platform-team\"\n  }\n}\n```\n\n## Configuration Breakdown\n\n| Parameter | Value | Description |\n|-----------|-------|-------------|\n| **FunctionName** | `my-lambda-function` | Unique name for the Lambda function |\n| **Runtime** | `python3.11` | Execution environment (node.js, java, go, etc.) |\n| **Role** | ARN format | IAM role with Lambda execution permissions |\n| **Handler** | `index.handler` | Entry point (file.function) |\n| **Timeout** | 30 | Max execution time in seconds (3-900) |\n| **MemorySize** | 256 | Memory allocation in MB (128-10,240) |\n\n## Additional Optional Fields\n\n- **Description**: Function purpose and details\n- **EphemeralStorage**: Temporary storage (512-10,240 MB)\n- **Environment**: Environment variables for the function\n- **Tags**: Resource tags for organization and billing\n\n## Alternative Runtime Examples\n\n```json\n{\n  \"Runtime\": \"nodejs.20.x\",      // Node.js\n  \"Runtime\": \"java17\",            // Java\n  \"Runtime\": \"go1.x\",             // Go\n  \"Runtime\": \"dotnet8\",           // .NET\n  \"Runtime\": \"ruby3.3\"            // Ruby\n}\n```\n\nThis configuration is ready for use with AWS CLI or SDK calls to create or update Lambda functions.",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function with basic settings (function name, runtime, role ARN, timeout, memory)",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution successfully addresses the core requirements with a clean, well-documented JSON configuration and helpful supplementary information. However, it presents potential usability issues through hardcoded values without sufficient warnings, lacks guidance on important production configurations, and doesn't adequately explain runtime-specific variations. The documentation quality is strong but practical guidance for real-world deployment is incomplete."
#   },
#   {
#     "output": "# AWS Account ID Extraction from IAM ARN\n\nHere's a Python function that extracts the AWS account ID from an IAM ARN string:\n\n```python\ndef extract_account_id(arn: str) -> str:\n    \"\"\"\n    Extracts the AWS account ID from an IAM ARN string.\n    \n    Args:\n        arn (str): IAM ARN string in format: arn:aws:iam::123456789012:user/username\n        \n    Returns:\n        str: The AWS account ID (12-digit string)\n        \n    Raises:\n        ValueError: If the ARN format is invalid\n    \"\"\"\n    try:\n        # Split the ARN by colons\n        parts = arn.split(':')\n        \n        # IAM ARN format: arn:aws:iam::ACCOUNT_ID:resource\n        # parts[0] = 'arn'\n        # parts[1] = 'aws'\n        # parts[2] = 'iam'\n        # parts[3] = '' (empty for IAM)\n        # parts[4] = ACCOUNT_ID\n        \n        if len(parts) < 5:\n            raise ValueError(\"Invalid ARN format\")\n        \n        account_id = parts[4]\n        \n        if not account_id or not account_id.isdigit() or len(account_id) != 12:\n            raise ValueError(\"Invalid AWS account ID\")\n        \n        return account_id\n    \n    except (IndexError, AttributeError):\n        raise ValueError(f\"Invalid ARN format: {arn}\")\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test 1: Standard IAM user ARN\n    arn1 = \"arn:aws:iam::123456789012:user/username\"\n    print(f\"ARN: {arn1}\")\n    print(f\"Account ID: {extract_account_id(arn1)}\")  # Output: 123456789012\n    print()\n    \n    # Test 2: IAM role ARN\n    arn2 = \"arn:aws:iam::987654321098:role/MyRole\"\n    print(f\"ARN: {arn2}\")\n    print(f\"Account ID: {extract_account_id(arn2)}\")  # Output: 987654321098\n    print()\n    \n    # Test 3: IAM policy ARN\n    arn3 = \"arn:aws:iam::111111111111:policy/MyPolicy\"\n    print(f\"ARN: {arn3}\")\n    print(f\"Account ID: {extract_account_id(arn3)}\")  # Output: 111111111111\n    print()\n    \n    # Test 4: Invalid ARN (should raise error)\n    try:\n        arn4 = \"arn:aws:iam::12345:user/username\"\n        extract_account_id(arn4)\n    except ValueError as e:\n        print(f\"Error: {e}\")\n```\n\n## Alternative Solution (Using Regex)\n\n```python\nimport re\n\ndef extract_account_id_regex(arn: str) -> str:\n    \"\"\"\n    Extracts the AWS account ID from an IAM ARN using regex.\n    \n    Args:\n        arn (str): IAM ARN string\n        \n    Returns:\n        str: The AWS account ID\n        \n    Raises:\n        ValueError: If the ARN format is invalid\n    \"\"\"\n    match = re.search(r'arn:aws:iam::(\\d{12}):', arn)\n    \n    if not match:\n        raise ValueError(f\"Invalid IAM ARN format: {arn}\")\n    \n    return match.group(1)\n\n\n# Test\nprint(extract_account_id_regex(\"arn:aws:iam::123456789012:user/username\"))  # Output: 123456789012\n```\n\n## Output\n\n```\nARN: arn:aws:iam::123456789012:user/username\nAccount ID: 123456789012\n\nARN: arn:aws:iam::987654321098:role/MyRole\nAccount ID: ",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS account ID from an IAM ARN string (arn:aws:iam::123456789012:user/username)",
#       "format": "python"
#     },
#     "score": 8,
#     "reasoning": "The solution correctly solves the stated task with well-implemented functions featuring proper error handling and validation. The code is clean, readable, and includes helpful comments. However, the incomplete output section and narrow focus on only IAM ARNs (without acknowledging other ARN types) slightly diminish the overall quality. The core functionality is sound and production-ready."
#   }
# ]
